# %% [markdown]
# ### Dashboard Google analytics
#
# O dashboard abaixo apresenta uma análise geral de um conjunto de dados (fictícios) obtidos a partir do google analytics. A análise mostra resumidamente os principais meios de acesso ao site, a análise da receita por canais de acesso e a evolução da mesma ao longo do período analisado. Isso ajudará a entender as preferências e o perfil dos clientes da loja, bem como na realocação de recursos de modo mais eficiente.

# %%
from IPython.display import Image
Image ("C:/Users/LNV/Documents/Pasta_matheus/GA_analyticsDASH.png")

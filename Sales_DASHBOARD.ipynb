# %% [markdown]
# #### SALES OVERVIEW DASHBOARD

# %% [markdown]
# O dashboard abaixo apresenta uma análise ampla sobre as vendas da empresa. A análise mostra uma visão geral sobre o faturamento e o lucro da empresa, bem os segmentos mais lucrativos, os meses em que os lucros ficaram acima da média e as épocas do ano em que as vendas tendem a aumentar.

# %%
from IPython.display import Image
Image ("C:/Users/LNV/Documents/Pasta_matheus/Portfolio/BID_portfolio01.png")

# %%
from IPython.display import Image
Image ("C:/Users/LNV/Documents/Pasta_matheus/Portfolio/BID_portfolio02.png")

# %%
from IPython.display import Image
Image ("C:/Users/LNV/Documents/Pasta_matheus/Portfolio/BID_portfolio03.png")

# %% [markdown]
# Quaisquer dúvidas sobre a apresentação do dashboard ou semelhante, estou à disposição para esclarecimentos.
